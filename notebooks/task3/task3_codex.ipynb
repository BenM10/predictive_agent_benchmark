# %% [markdown]
# # Task 3 - Baseline Model Training
#
# This notebook runs the modular Task 3 baseline modelling workflow for passenger satisfaction prediction.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve()
if not (project_root / "results").exists():
    project_root = project_root.parents[1]
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from results.codex.task3.generated_code import main

metrics_df, fitted_models = main()
metrics_df
# Out:
# Loading dataset from: data/processed/Codex_clean.csv
# Dataset shape: (129880, 24)
# Training rows: 103904, Test rows: 25976
# Categorical features: ['Gender', 'Customer Type', 'Type of Travel', 'Class']
# Numeric features: ['Age', 'Flight Distance', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes']
#
# === Baseline Model Metrics ===
#                model  accuracy       f1  roc_auc
# HistGradientBoosting  0.963312 0.957016 0.994875
#        Random Forest  0.962003 0.955583 0.993984
#  Logistic Regression  0.874192 0.852274 0.927250
# Saved figure 1 to: figures/Icodex/fig_01_baseline_model_metrics.png
# Saved figure 2 to: figures/Icodex/fig_02_roc_curves.png
# ...
