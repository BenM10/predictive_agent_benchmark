# %% [markdown]
# # Task 2 - Exploratory Data Analysis (EDA)
#
# This notebook runs the generated experiment code for Task 2 to perform
# exploratory data analysis on `data/processed/codex_clean.csv`.
#
# It loads the dataset, explores its structure, identifies important
# variables and distributions, generates up to seven visualisations (saved via `save_and_show` to `figures/codex/`), and
# highlights interesting patterns related to passenger satisfaction.

# %%
import sys
from pathlib import Path
import pandas as pd

project_root = Path.cwd().resolve()
if not (project_root / "results").exists():
    project_root = project_root.parents[1]
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from results.codex.task2.generated_code import main

# Run the EDA (prints summaries and saves figures)
main()

# Load the dataframe for further analysis
csv_path = project_root / "data" / "processed" / "codex_clean.csv"
df = pd.read_csv(csv_path)
numeric_df = df.select_dtypes(include=["number"])

df.head(), numeric_df.head()
# Out:
# Loading dataset from: data/processed/codex_clean.csv
#
# === Basic Structure ===
# Shape (rows, columns): (129880, 24)
#
# Columns:
# ['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class', 'Flight Distance', 'Inflight wifi service', 'Departure/Arrival time convenient', 'Ease of Online booking', 'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort', 'Inflight entertainment', 'On-board service', 'Leg room service', 'Baggage handling', 'Checkin service', 'Inflight service', 'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes', 'satisfaction']
#
# Data types:
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# ...

# %%
from pathlib import Path
from IPython.display import Image, display

# Display all saved Task 2 figures explicitly in the notebook
fig_dir = (Path.cwd() / "figures" / "codex").resolve()
print(f"Loading figures from: {fig_dir}")

if not fig_dir.exists():
    print("No figures directory found yet. Run the previous EDA cell first.")
else:
    image_paths = sorted(fig_dir.glob("fig_*.png"))
    if not image_paths:
        print("No saved figures found in figures/codex. Run the previous EDA cell first.")
    else:
        for img_path in image_paths:
            print(f"\nShowing: {img_path.name}")
            display(Image(filename=str(img_path)))
# Out:
# Loading figures from: /Users/daphnethorne/Downloads/predictive_agent_benchmark-main/notebooks/task2/figures/codex
# No figures directory found yet. Run the previous EDA cell first.
