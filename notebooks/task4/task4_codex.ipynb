# %% [markdown]
# # Task 4 - Improving Model Performance
#
# This notebook runs the modular Task 4 workflow to improve and compare predictive performance against a held-out baseline.

# %%
import sys
from pathlib import Path

project_root = Path.cwd().resolve()
if not (project_root / "results").exists():
    project_root = project_root.parents[1]
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from results.codex.task4.generated_code import main

comparison_df, best_params = main()
comparison_df
# Out:
# Loading dataset from: data/processed/codex_clean.csv
# Dataset shape: (129880, 24)
# Training rows: 103904, Test rows: 25976
#
# === Best Hyperparameters ===
# {'model__min_samples_leaf': 40, 'model__max_leaf_nodes': 127, 'model__max_depth': None, 'model__max_bins': 191, 'model__learning_rate': 0.08, 'model__l2_regularization': 0.1}
#
# === Baseline vs Improved Performance ===
#                               model  accuracy       f1  roc_auc  accuracy_delta_vs_baseline  f1_delta_vs_baseline  roc_auc_delta_vs_baseline
#       Baseline HistGradientBoosting  0.963312 0.957016 0.994875                    0.000000              0.000000                   0.000000
# Improved Tuned HistGradientBoosting  0.964198 0.958063 0.995168                    0.000885              0.001047                   0.000293
# Saved figure 1 to: figures/codex/fig_01_baseline_vs_improved_metrics.png
# Figure(800x500)
# Saved figure 2 to: figures/codex/fig_02_roc_comparison.png
# Figure(700x500)
# ...
